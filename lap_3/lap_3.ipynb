# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np 

image_path = 'cat.jpg'

# 1) Read color image
img = cv2.imread(image_path)


print("Image datatype:", type(img))
print("Image shape (H, W, Channels):", img.shape)

    # OpenCV reads BGR → convert to RGB for display
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.title("Original Image")
    plt.axis('off')
    plt.show()

    # 2) Convert to Grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    plt.imshow(gray, cmap='gray')
    plt.title("Grayscale")
    plt.axis('off')
    plt.show()

    # 3) Save grayscale
    cv2.imwrite('output.jpg', gray)

    # 4) Convert to YUV
    yuv_img = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)

    # Show channels
    titles = ['Y (Brightness)', 'U (Blue info)', 'V (Red info)']
    for i in range(3):
        plt.imshow(yuv_img[:, :, i], cmap='gray')
        plt.title(titles[i])
        plt.axis('off')
        plt.show()

    # 5) Print color conversion flags
    color_flags = [x for x in dir(cv2) if x.startswith('COLOR_')]
    print("Number of color conversion options:", len(color_flags))
# Out:
# Image datatype: <class 'numpy.ndarray'>
# Image shape (H, W, Channels): (182, 277, 3)
# Number of color conversion options: 374

# %% [markdown]
# ### Task1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image
img = cv2.imread('cat.jpg')

# Get dimensions
(h, w) = img.shape[:2]

# 1) Increase size (Resize 2x)
resized = cv2.resize(img_rgb, None, fx=2, fy=2, interpolation=cv2.INTER_LINEAR)
print(resized.size)

# 2) Rotate 120 degrees
center = (w//2, h//2)
rot_matrix = cv2.getRotationMatrix2D(center, 120, 1.0)
rotated = cv2.warpAffine(img_rgb, rot_matrix, (w, h))

# 3) Shear transformation
shear_matrix = np.float32([[1, 0.5, 0],
                           [0.2, 1, 0]])
sheared = cv2.warpAffine(img_rgb, shear_matrix, (int(w*1.5), int(h*1.5)))

# Display results
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.imshow(img_rgb)
plt.title("Original")
plt.axis('off')

plt.subplot(2,2,2)
plt.imshow(resized)
plt.title("Resized (2x)")
plt.axis('off')

plt.subplot(2,2,3)
plt.imshow(rotated)
plt.title("Rotated 120°")
plt.axis('off')

plt.subplot(2,2,4)
plt.imshow(sheared)
plt.title("Sheared")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 604968
